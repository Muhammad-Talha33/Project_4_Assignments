# %% [markdown]
# ## **We want you to gain more experience working with control flow and Booleans in Python. To do this, we are going to have you develop a game! The game is called High-Low and the way it's played goes as follows:**
#
# ### Two numbers are generated from 1 to 100 (inclusive on both ends): one for you and one for a computer, who will be your opponent. You can see your number, but not the computer's!
#
# ### You make a guess, saying your number is either higher than or lower than the computer's number
#
# ### If your guess matches the truth (ex. you guess your number is higher, and then your number is actually higher than the computer's), you get a point!
#
# ### These steps make up one round of the game. The game is over after all rounds have been played.

# %%
import random

NUM_ROUNDS = 5
print("Welcome to the High-Low Game!")
print('--------------------------------')

def spaces():
  print()

def main():
 score = 0

 for i in range(NUM_ROUNDS):
    print(f"Round {i+1}")
    user_num = random.randint(1,100)
    print("Your number is",user_num)

    comp_num = random.randint(1,100)
    user_input = input("Do you think your number is higher or lower than the computer's?: ")

    while user_input != "higher" and user_input != "lower":
      user_input = input("Invalid input, please type ‘higher’ or ‘lower’. ")

    if user_input.lower() == "higher":
       if user_num > comp_num:
        print(f"You were right! The computer's number was {comp_num}")
        score += 1
        print(f"Round {i+1} - Your score is",score)
        spaces()
       else:
        print(f"Aww, that's incorrect. The computer's number was {comp_num}")
        spaces()
    elif user_input.lower() == "lower":
        if user_num < comp_num:
         print(f"You were right! computer number is {comp_num}")
         score += 1
         print(f"Round {i+1} - Your score is",score)
         spaces()
        else:
          print(f"Aww, that's incorrect. The computer's number was {comp_num}")
          spaces()
    else:
       print("Please enter correctly")
 print(f"Game over your final score is {score}")
 spaces()

 if score == NUM_ROUNDS:
  print(f"You scored a perfect {score} out of {NUM_ROUNDS}! Wow, You played perfectly!")
 elif score >= NUM_ROUNDS // 2:
  print(f"Great job! You scored {score} out of {NUM_ROUNDS}!")
 else:
  print(f"Keep trying! Your score was {score} out of {NUM_ROUNDS}. Don't give up!")

 print("Thanks for playing!")


if __name__ == '__main__':
  main()
# Out:
# Welcome to the High-Low Game!
# --------------------------------
# Round 1
# Your number is 67
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 41
# Round 1 - Your score is 1
#
# Round 2
# Your number is 98
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 69
# Round 2 - Your score is 2
#
# Round 3
# Your number is 44
# Do you think your number is higher or lower than the computer's?: lower
# You were right! computer number is 91
# Round 3 - Your score is 3
#
# Round 4
# Your number is 62
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 36
# Round 4 - Your score is 4
#
# Round 5
# Your number is 63
# Do you think your number is higher or lower than the computer's?: higher
# You were right! The computer's number was 8
# Round 5 - Your score is 5
#
# ...
