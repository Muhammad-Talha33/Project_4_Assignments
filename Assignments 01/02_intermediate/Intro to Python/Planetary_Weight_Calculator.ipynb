# %% [markdown]
# ## **Write a Python program that prompts an Earthling to enter their weight on Earth and then to enter the name of a planet in our solar system. The program should print the equivalent weight on that planet rounded to 2 decimal places if necessary.**
#
# ### You can assume that the user will always type in a planet with the first letter capitalized and you do not need to worry about the case where they type in something other than one of the above planets.

# %%
def main():

 earth_weight_input = input("Enter a weight on Earth: ")
 earth_weight = float(earth_weight_input)

 selected_planet = input("Enter a planet: ")

 gravity_factors = { "Mercury": 0.376, "Venus": 0.889, "Mars": 0.378, "Jupiter": 2.36, "Saturn": 1.081, "Uranus": 0.815, "Neptune": 1.14 }

 """ This loop was intended to repeatedly prompt the user until they enter a valid planet name.
 It helps guide the user by listing acceptable options.
 Since the requirement says you don’t need to handle invalid inputs beyond Earth,
 this part can remain commented, but it's a good user-friendly addition if needed.
 Valid options include: Mercury, Venus, Mars, Jupiter, Saturn, Uranus, Neptune.
 Make sure the first letter of the planet is uppercase, as required.
  while selected_planet not in gravity_factors:
   selected_planet = input("Invalid input. Please enter a valid planet name: Mercury, Venus, Mars, Jupiter, Saturn, Uranus, Neptune. ")
 """

 if selected_planet in gravity_factors:
     gravity_factor = gravity_factors[selected_planet]
     planet_weight = earth_weight * gravity_factor
     print(f"The equivalent weight on {selected_planet}: {round(planet_weight,2)}")
 else:
  print("Invalid planet name.")

if __name__ == '__main__':
  main()
# Out:
# Enter a weight on Earth: 120
# Enter a planet: Mars
# The equivalent weight on Mars: 45.36
