# %% [markdown]
# ## **Simulate rolling two dice, three times. Prints the results of each die roll. This program is used to show how variable scope works.**

# %%
dice1 = 3
dice2 = 5
print(f"Roll 1: {dice1} and {dice2}")
dice1 = 6
dice2 = 2
print(f"Roll 2: {dice1} and {dice2}")
dice1 = 4
dice2 = 3
print(f"Roll 3: {dice1} and {dice2}")
# Out:
# Roll 1: 3 and 5
# Roll 2: 6 and 2
# Roll 3: 4 and 3
