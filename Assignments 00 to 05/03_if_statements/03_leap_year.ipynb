# %% [markdown]
# ## **Write a program that reads a year from the user and tells whether a given year is a leap year or not.**
#
# ### A leap year (also known as an intercalary year or bissextile year) is a calendar year that contains an additional day (or, in the case of a lunisolar calendar, a month) added to keep the calendar year synchronized with the astronomical year or seasonal year. In the Gregorian calendar, each leap year has 366 days instead of 365, by extending February to 29 days rather than the common 28.
#
# ### In the Gregorian calendar, three criteria must be checked to identify leap years:
#
# ### The given year must be evenly divisible by 4;
# ### If the year can also be evenly divided by 100, it is NOT a leap year; unless:
# ### The year is also evenly divisible by 400. Then it is a leap year.
# ### Your code should use the above criteria to check for a leap year and then print either "That's a leap year!" or "That's not a leap year."

# %%
def main():
  year_input = input("Which year do you want to check whether it's leap year or not ")
  year_to_check = int(year_input)

  if year_to_check % 400 == 0:
    print(f"Yes! {year_to_check} is a leap year with 366 days.")
  elif year_to_check % 100 == 0:
    print(f"{year_to_check} is not a leap year — it has 365 days.")
  elif year_to_check % 4 == 0:
    print(f"Yes! {year_to_check} is a leap year with 366 days.")
  else:
    print(f"{year_to_check} is not a leap year — it has 365 days.")

if __name__ == '__main__':
 main()
# Out:
# Which year do you want to check whether it's leap year or not 2008
# Yes! 2008 is a leap year with 366 days.
